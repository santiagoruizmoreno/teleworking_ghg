# %%
# !pip install wheel
# !pip install pandas
# !pip install plotly
# !pip install numpy
# !pip install matplotlib
# !pip install kaleido
# !pip3 install nbformat
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
### Importing the needed packages
import pandas as pd
import numpy as np
import os
import matplotlib
import nbformat

# %%
# Setting the directory: Maybe instead of modifying this line, you can add a new line with your path
os.chdir("/Users/marie/Desktop/Papier/Data")

# %%
apple_data = pd.read_csv("applemobilitytrends-2021-05-02.csv")
apple_data
# Out:
# /Users/marie/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             geo_type        region transportation_type alternative_name  \
# 0     country/region       Albania             driving              NaN
# 1     country/region       Albania             walking              NaN
# 2     country/region     Argentina             driving              NaN
# 3     country/region     Argentina             walking              NaN
# 4     country/region     Australia             driving               AU
# ...              ...           ...                 ...              ...
# 4686          county   York County             walking              NaN
# 4687          county  Young County             driving              NaN
# 4688          county   Yuba County             driving              NaN
# ...

# %%
apple_data = apple_data.rename(columns={'sub-region': 'sub_region'})
apple_data
# Out:
#             geo_type        region transportation_type alternative_name  \
# 0     country/region       Albania             driving              NaN
# 1     country/region       Albania             walking              NaN
# 2     country/region     Argentina             driving              NaN
# 3     country/region     Argentina             walking              NaN
# 4     country/region     Australia             driving               AU
# ...              ...           ...                 ...              ...
# 4686          county   York County             walking              NaN
# 4687          county  Young County             driving              NaN
# 4688          county   Yuba County             driving              NaN
# 4689          county   Yuma County             driving              NaN
# 4690          county   Yuma County             walking              NaN
#
#         sub_region        country  1/13/2020  1/14/2020  1/15/2020  1/16/2020  \
# ...

# %%
apple_data_california = apple_data[apple_data.sub_region == "California"]
apple_data_california
# Out:
#      geo_type          region transportation_type alternative_name  \
# 183      city         Antioch             driving              NaN
# 184      city         Antioch             transit              NaN
# 185      city         Antioch             walking              NaN
# 202      city     Bakersfield             driving              NaN
# 203      city     Bakersfield             transit              NaN
# ...       ...             ...                 ...              ...
# 4477   county  Ventura County             walking              NaN
# 4677   county     Yolo County             driving              NaN
# 4678   county     Yolo County             transit              NaN
# 4679   county     Yolo County             walking              NaN
# 4688   county     Yuba County             driving              NaN
#
#       sub_region        country  1/13/2020  1/14/2020  1/15/2020  1/16/2020  \
# 183   California  United States      100.0     100.70     100.63     100.34
# ...

# %%
apple_data_california = apple_data[apple_data.sub_region == "California"]
apple_data_california
# Out:
#      geo_type          region transportation_type alternative_name  \
# 183      city         Antioch             driving              NaN
# 184      city         Antioch             transit              NaN
# 185      city         Antioch             walking              NaN
# 202      city     Bakersfield             driving              NaN
# 203      city     Bakersfield             transit              NaN
# ...       ...             ...                 ...              ...
# 4477   county  Ventura County             walking              NaN
# 4677   county     Yolo County             driving              NaN
# 4678   county     Yolo County             transit              NaN
# 4679   county     Yolo County             walking              NaN
# 4688   county     Yuba County             driving              NaN
#
#       sub_region        country  1/13/2020  1/14/2020  1/15/2020  1/16/2020  \
# 183   California  United States      100.0     100.70     100.63     100.34
# ...

# %%
apple_data_california.apply (lambda row: label_race(row), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d_/bbd0y38s1w99d__mf5rzc5dh0000gn/T/ipykernel_26256/3808754556.py in <module>
# ----> 1 apple_data_california.apply (lambda row: label_race(row), axis=1)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8734             kwargs=kwargs,
#    8735         )
# -> 8736         return op.apply()
#    8737
#    8738     def applymap(
#
# /usr/local/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     803
#     804     def apply_standard(self):
# ...
